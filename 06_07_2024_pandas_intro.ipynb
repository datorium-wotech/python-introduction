# %%
import pandas as pd

# %%
data_list =  [1,2,3,4,5] #list
print(data_list)
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# ### Pandas series

# %%
series_from_list = pd.Series(data_list)
print(series_from_list)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ### Pandas DataFrame

# %%
dataframe_from_list = pd.DataFrame(data_list)
print(dataframe_from_list)
# Out:
#    0
# 0  1
# 1  2
# 2  3
# 3  4
# 4  5

# %% [markdown]
# ### Pandas Series from dictionary

# %%
data_dict = {'A': 10, 'B': 20, 'C': 30, 'D': 40, 'E': 50} #dictionary object key-value pairs

series_from_dict = pd.Series(data_dict)
print(series_from_dict)

#dtype: int64 - integer values
# Out:
# A    10
# B    20
# C    30
# D    40
# E    50
# dtype: int64

# %%
csv_data = "1,2,3,4,5" #string
csv_data.split(',') #split the string into a list
# Out:
# ['1', '2', '3', '4', '5']

# %%
series_from_list_split = pd.Series(csv_data.split(','))
print(series_from_list_split)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: object

# %% [markdown]
# ### DataFrames

# %%
data_list = [
    ['John', 30, 68.5, True, 95.5],
    ['Alice', 25, 63.2, False, 88.0],
    ['Bob', 35, 71.0, True, 76.5],
    ['Eve', 28, 65.8, False, 92.0],
    ['Charlie', 40, 72.3, False, 87.5]
]

column_names = ['Name', 'Age', 'Weight', 'Is Student', 'Score']

pd.DataFrame(data_list, columns=column_names)
# Out:
#       Name  Age  Weight  Is Student  Score
# 0     John   30    68.5        True   95.5
# 1    Alice   25    63.2       False   88.0
# 2      Bob   35    71.0        True   76.5
# 3      Eve   28    65.8       False   92.0
# 4  Charlie   40    72.3       False   87.5

# %% [markdown]
# ### Working with a CSV file

# %%
df = pd.read_csv('/content/transaction_dataset.csv') #we have read in the file

# %%
df.tail() #last 5 rows of dataframe

df.shape #number of rows and columns

df.sample(5) #random sample

df.info() #column names, data types (Dtype), how many values NaN - not a number
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Customer ID         50000 non-null  int64
#  1   Name                50000 non-null  object
#  2   Surname             50000 non-null  object
#  3   Gender              44953 non-null  object
#  4   Birthdate           50000 non-null  object
#  5   Transaction Amount  50000 non-null  float64
#  6   Date                50000 non-null  object
#  7   Merchant Name       50000 non-null  object
#  8   Category            50000 non-null  object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 3.4+ MB
#         Customer ID  Transaction Amount
# count   50000.00000        50000.000000
# mean   500136.79696          442.119239
# std    288232.43164          631.669724
# min        29.00000            5.010000
# 25%    251191.50000           79.007500
# ...

# %%
df.describe() #summary statistics of integers/floats
# Out:
#         Customer ID  Transaction Amount
# count   50000.00000        50000.000000
# mean   500136.79696          442.119239
# std    288232.43164          631.669724
# min        29.00000            5.010000
# 25%    251191.50000           79.007500
# 50%    499520.50000          182.195000
# 75%    749854.25000          470.515000
# max    999997.00000         2999.880000

# %%
df.describe(include='object') #summary statistics of strings
# Out:
#            Name Surname Gender   Birthdate        Date Merchant Name  \
# count     50000   50000  44953       50000       50000         50000
# unique      690    1000      2          58         287         36939
# top     Michael   Smith      F  01/11/1954  30/06/2023     Smith Ltd
# freq       1167    1095  22713         914         200            69
#
#           Category
# count        50000
# unique           6
# top     Restaurant
# freq          8413

# %%
df.head()
# Out:
#    Customer ID      Name    Surname Gender   Birthdate  Transaction Amount  \
# 0       752858      Sean  Rodriguez      F  20/10/2002               35.47
# 1        26381  Michelle     Phelps    NaN  24/10/1985             2552.72
# 2       305449     Jacob   Williams      M  25/10/1981              115.97
# 3       988259    Nathan     Snyder      M  26/10/1977               11.31
# 4       764762   Crystal      Knapp      F  02/11/1951               62.21
#
#          Date               Merchant Name     Category
# 0  03/04/2023               Smith-Russell     Cosmetic
# 1  17/07/2023      Peck, Spence and Young       Travel
# 2  20/09/2023                  Steele Inc     Clothing
# 3  11/01/2023  Wilson, Wilson and Russell     Cosmetic
# 4  13/06/2023               Palmer-Hinton  Electronics

# %%
# How to select 1 column in a DataFrame?
df['Gender']

# How many unique values?

df['Gender'].unique()
# Out:
# array(['F', nan, 'M'], dtype=object)

# %%
df['Gender'] # we access column by a name, we can access several columns

df.Gender # accessing column with an attribute

df.iloc[:, 3] # accessing column with index [row, column]
# Out:
# 0          F
# 1        NaN
# 2          M
# 3          M
# 4          F
#         ...
# 49995      F
# 49996      F
# 49997      M
# 49998      M
# 49999      F
# Name: Gender, Length: 50000, dtype: object

# %%
# value counts

df['Gender'].value_counts(dropna=False)
# Out:
# Gender
# F      22713
# M      22240
# NaN     5047
# Name: count, dtype: int64

# %%
df.isna() #ginary False = 0, True = 1

df.isna().sum()

df.notna().sum()

df.notna().all()
# Out:
# Customer ID            True
# Name                   True
# Surname                True
# Gender                False
# Birthdate              True
# Transaction Amount     True
# Date                   True
# Merchant Name          True
# Category               True
# dtype: bool

# %%
### Drop empty values

df.dropna() #did not override

df.dropna(inplace=True)

# %%
df_new_dataframe = df.dropna() #save it in new df

df.dropna(inplace=True) # specify that you want to override existing df

# %%
# Saving the cleaned file

df.to_csv('cleaned_data.csv')
